# %% [markdown]
# ### Modules

# %% [markdown]
# A Python module is a file containing Python definitions and statements. A module can define functions, classes, and variables. A module can also include runnable code. Grouping related code into a module makes the code easier to understand and use. It also makes the code logically organized.

# %% [markdown]
# #### every module have seperate namespace

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#### Best pratice is to donwload the entire package and use dot operator to access the methods
#### Alterantively you can import functions ,varaiable from modules with alias name

# %%
import math
from math import sqrt as mathsqrt

# %%
#### Importing specific functions and variable may cause name space confusion

# %%
import math

def sin(x):
    if 2 * x == pi:
        return 0.99999999
    else:
        return None

pi = 3.14
print(sin(pi/2))
print(math.sin(math.pi/2))
# Out:
# 0.99999999
# 1.0

# %%
## from module import *
## import module as alias

# %%
# dr method to explore the available functions in a module
import math

for n in dir(math):
    print(n,end="\t")
# Out:
# __doc__	__loader__	__name__	__package__	__spec__	acos	acosh	asin	asinh	atan	atan2	atanh	ceil	comb	copysign	cos	cosh	degrees	dist	e	erf	erfc	exp	expm1	fabs	factorial	floor	fmod	frexp	fsum	gamma	gcd	hypot	inf	isclose	isfinite	isinf	isnan	isqrt	lcm	ldexp	lgamma	log	log10	log1p	log2	modf	nan	nextafter	perm	pi	pow	prod	radians	remainder	sin	sinh	sqrt	tan	tanh	tau	trunc	ulp

# %%
### How to import python file to a notebook

# %% [markdown]
# # Packages
#
#     package; in the world of modules, a package plays a similar role to a folder/directory in the world of files.
#
#     package is as collection of related modules
#
#    ![image.png](attachment:image.png)

# %% [markdown]
# ## name dunder variable
#
#     when you run a file directly, its __name__ variable is set to __main__;
#     when a file is imported as a module, its __name__ variable is set to the file's name (excluding .py)

# %% [markdown]
# ## What happens in import a module
#
#     The imported file is executed if the module is imported twice but it will be executed once

# %% [markdown]
# ####  In python there is no concept of private variables so to make a private variable we add __ or _ underscore before the variable __counter

# %%
# python will search for the module in the below folder paths

# %%
import sys

for p in sys.path:
    print(p)
# Out:
# C:\Users\Lenovo\OneDrive - Синерджи Глобал Файненшъл Солюшънс ЕООД\Desktop\Python_projects\PCAP\PCAP_Notebooks
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\python310.zip
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\DLLs
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310
#
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\win32
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\win32\lib
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\Pythonwin
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\extensions
# C:\Users\Lenovo\.ipython

# %% [markdown]
# #### we can append the new folder to the sys patyhn list like sys.path.append("..//modulesfolder")

# %% [markdown]
# #### You need to use a different trick instead - Python expects that there is a file with a very unique name inside the package's folder: \__init\__.py.

# %%
### some pip commands

### if pip not installed in linux we can install using the command sudo apt install
### pip install --user pygame  => this will install for the user not globaly
## pip install package_name==package_version   -- to install particular version of a package
### pip uninstall packagename -- to uninstall a package
#### pip install packages expansion for pip
