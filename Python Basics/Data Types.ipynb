# %% [markdown]
#  ####  int,float,complex,bool,string and bytes are 6 basic data types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <i style="color:red"> Numeric data type consist of oct,hex and binary</i>

# %% [markdown]
# ![image.png](attachment:image.png)
